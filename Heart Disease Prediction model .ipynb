# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns

# %%
data=pd.read_csv("C:/Users/bansa/Downloads/heart.data_/heart.data.csv")
sns.pairplot(data)
# Out:
# C:\Users\bansa\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
x=data[['biking','smoking']]
y=data['heart.disease']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test, y_train, y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression 
model=LinearRegression()

# %%
model.fit(x_train, y_train)
print(model.coef_)
# Out:
# [-0.19975628  0.17711904]

# %%
print(model.intercept_)
# Out:
# 14.954225819333383

# %%
pd.DataFrame(model.coef_, x.columns, columns =['Coeff'])
# Out:
#             Coeff
# biking  -0.199756
# smoking  0.177119

# %%
predictions=model.predict(x_test)
plt.scatter(y_test, predictions)

# %%
plt.hist(y_test-predictions)
# Out:
# (array([ 1.,  4.,  2., 16., 26., 33., 34., 20., 11.,  3.]),
#  array([-2.01025328, -1.63899932, -1.26774536, -0.8964914 , -0.52523744,
#         -0.15398347,  0.21727049,  0.58852445,  0.95977841,  1.33103237,
#          1.70228633]),
#  <BarContainer object of 10 artists>)

# %%
from sklearn import metrics
metrics.mean_absolute_error(y_test, predictions)
# Out:
# 0.5123010913356222

# %%
np.sqrt(metrics.mean_squared_error(y_test, predictions))
# Out:
# 0.6503700743206275
